# %%
import pandas as pd                # データの形を整えるのも
import matplotlib.pyplot as plt    # 図を描くためのもの１
import seaborn as sns              # 図を描くためのもの２
# %matplotlib inline                 # jupyterで図を表示させる
plt.style.use('ggplot')            # 図のスタイルを決める、今回は「ggplot」
import japanize_matplotlib         # 図に日本語を表示させる
import warnings                    # 警告メッセージを表示させない
warnings.filterwarnings('ignore')  # 上と同じ

print(sns.__version__)             # seabornのバージョンを確認
# Out:
# UsageError: unrecognized arguments: # jupyterで図を表示させる

# %%
df = pd.read_csv("bestsong.csv")

# %%
df
# Out:
#                         uri              name                album  \
# 0    2bzdhN6Y5AP1zRRf12QwJq               キセキ                  キセキ
# 1    1Rvh5RimhF3ndpclBmIdeJ            そばにいるね               そばにいるね
# 2    52mKiP16FYA0C8X6gTr4zK  I AM YOUR SINGER     I AM YOUR SINGER
# 3    0AU7xhipAm9Saq0k8A9Iua            HANABI  SUPERMARKET FANTASY
# 4    7cWujxmEVy0ru9y1uGCs4N              LIFE                 LIFE
# ..                      ...               ...                  ...
# 977  5gh0y6ZmuppQvoPbAGkeE2           愛を知るまでは              愛を知るまでは
# 978  7Fuv1ELyHOYkRbPvRpN4vo         Rocketeer            Rocketeer
# 979  22sQUmLhT8umlEhQzDrzfJ               第六感                  第六感
# 980  2sQDwbzGSpHXwnIAOrcDn9            グッバイ宣言               グッバイ宣言
# 981  4W29WmnGN1FlufURaBt8yw             怪獣の花唄               strobo
#
#             artist  genre release_date  length  mode  popularity  \
# 0          GReeeeN      0   2008-06-04  271880     1          51
# ...

# %%
#散布図
plt.scatter(df['valence'],df['energy'])

plt.show()

# %%
#図の大きさ、解像度
plt.figure(figsize=(8,5),dpi=150)
#点の大きさ、透過、縁
plt.scatter(df['valence'], df['energy'], s=30, alpha=0.5, c='black',edgecolors="w")
#タイトル
plt.title('sanpuzu', fontsize=30)
#X軸
plt.xlabel('Valence', fontsize=20)
#X軸
plt.ylabel('Energy', fontsize=20)

plt.show()

# %%
sns.jointplot(x='valence', y='energy', data=df, kind='reg', size=7)
plt.xlabel('Valence', fontsize=20)
plt.ylabel('Energy', fontsize=20)
# Out:
# c:\users\tamaki.i\appdata\local\programs\python\python38\lib\site-packages\seaborn\axisgrid.py:2182: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# Text(390.30000000000007, 0.5, 'Energy')

# %%
df2 = df[['danceability', 'acousticness', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',  'valence']]

# %%
df2
# Out:
#      danceability  acousticness  energy  instrumentalness  liveness  loudness  \
# 0           0.642       0.10300   0.616          0.000000     0.179    -4.259
# 1           0.671       0.41400   0.722          0.000078     0.174    -7.074
# 2           0.686       0.55800   0.816          0.000005     0.160    -5.220
# 3           0.638       0.15700   0.766          0.000000     0.124    -5.541
# 4           0.693       0.08860   0.937          0.000008     0.281    -4.742
# ..            ...           ...     ...               ...       ...       ...
# 977         0.564       0.05310   0.634          0.000003     0.128    -4.130
# 978         0.777       0.02460   0.854          0.000000     0.261    -4.289
# 979         0.675       0.00893   0.959          0.000085     0.325    -1.754
# 980         0.552       0.03200   0.905          0.000000     0.345    -4.992
# 981         0.425       0.00361   0.939          0.000000     0.331    -3.498
#
# ...

# %%
df2.to_csv("JPbest_audio.csv")

# %%
df3 = df[['danceability', 'energy',  'valence']]
df3
# Out:
#      danceability  energy  valence
# 0           0.642   0.616    0.317
# 1           0.671   0.722    0.790
# 2           0.686   0.816    0.942
# 3           0.638   0.766    0.595
# 4           0.693   0.937    0.793
# ..            ...     ...      ...
# 977         0.564   0.634    0.683
# 978         0.777   0.854    0.481
# 979         0.675   0.959    0.835
# 980         0.552   0.905    0.896
# 981         0.425   0.939    0.638
#
# [982 rows x 3 columns]

# %%
pg = sns.pairplot(df3)
print(type(pg))
# Out:
# <class 'seaborn.axisgrid.PairGrid'>

# %%
df = pd.read_csv("10000songs.csv")
sns.jointplot(x='loudness', y='energy', data=df, kind='reg', size=7)
plt.xlabel('loudness', fontsize=20)
plt.ylabel('Energy', fontsize=20)
# Out:
# c:\users\tamaki.i\appdata\local\programs\python\python38\lib\site-packages\seaborn\axisgrid.py:2182: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# Text(390.30000000000007, 0.5, 'Energy')

# %%
df
# Out:
#       Unnamed: 0        genre        artist_name  \
# 0         145914         Jazz     Caravan Palace
# 1         130463    Classical   Morten Lauridsen
# 2         201648   Soundtrack  Michael Giacchino
# 3         201692   Soundtrack       Jeremy Soule
# 4         176479         Jazz        Mike Garson
# ...          ...          ...                ...
# 9716        7323      Country       Brad Paisley
# 9717       38120   Electronic         Jamiroquai
# 9718      185095          Ska        Mad Caddies
# 9719       11797  Alternative          Inspector
# 9720      186565          Ska       Mustard Plug
#
#                                              track_name  \
# 0                                         Jolie coquine
# 1     O Magnum Mysterium (arr. H.R. Reynolds for win...
# 2                                    The Explorer Motel
# 3                                                draumr
# 4                                         Life on Mars?
# ...

# %%
df_a = df[['danceability', 'acousticness', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'valence']]

# %%
plt.rcParams['font.size'] = 10
fig, ax = plt.subplots(figsize=(10,10))

df_a.hist(ax=ax)
# Out:
# C:\Users\Tamaki.I\AppData\Local\Temp\ipykernel_15124\1564923818.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df_a.hist(ax=ax)
# array([[<AxesSubplot:title={'center':'danceability'}>,
#         <AxesSubplot:title={'center':'acousticness'}>,
#         <AxesSubplot:title={'center':'energy'}>],
#        [<AxesSubplot:title={'center':'instrumentalness'}>,
#         <AxesSubplot:title={'center':'liveness'}>,
#         <AxesSubplot:title={'center':'loudness'}>],
#        [<AxesSubplot:title={'center':'speechiness'}>,
#         <AxesSubplot:title={'center':'tempo'}>,
#         <AxesSubplot:title={'center':'valence'}>]], dtype=object)

# %%
df_V = df[['danceability', 'acousticness', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'valence']]
df_V
# Out:
#       danceability  acousticness  instrumentalness  liveness  loudness  \
# 0           0.7420       0.00756          0.000002    0.1240    -5.819
# 1           0.0925       0.99200          0.762000    0.3330   -26.473
# 2           0.1710       0.90400          0.957000    0.0910   -22.603
# 3           0.1620       0.99000          0.804000    0.0826   -29.768
# 4           0.3340       0.97400          0.878000    0.1090   -24.384
# ...            ...           ...               ...       ...       ...
# 9716        0.5040       0.35800          0.000104    0.4000    -5.170
# 9717        0.5760       0.09580          0.125000    0.3620    -6.494
# 9718        0.5390       0.12000          0.000092    0.1190    -4.388
# 9719        0.6710       0.02660          0.000209    0.0951    -3.868
# 9720        0.4810       0.00347          0.000012    0.3830    -3.593
#
#       speechiness    tempo  valence
# 0          0.3690  125.044   0.6040
# 1          0.0439   87.431   0.0357
# ...

# %%
df_V.to_csv("Valence_feature.csv")

# %%
df_E = df[['danceability', 'acousticness', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'energy']]
df_E
# Out:
#       danceability  acousticness  instrumentalness  liveness  loudness  \
# 0           0.7420       0.00756          0.000002    0.1240    -5.819
# 1           0.0925       0.99200          0.762000    0.3330   -26.473
# 2           0.1710       0.90400          0.957000    0.0910   -22.603
# 3           0.1620       0.99000          0.804000    0.0826   -29.768
# 4           0.3340       0.97400          0.878000    0.1090   -24.384
# ...            ...           ...               ...       ...       ...
# 9716        0.5040       0.35800          0.000104    0.4000    -5.170
# 9717        0.5760       0.09580          0.125000    0.3620    -6.494
# 9718        0.5390       0.12000          0.000092    0.1190    -4.388
# 9719        0.6710       0.02660          0.000209    0.0951    -3.868
# 9720        0.4810       0.00347          0.000012    0.3830    -3.593
#
#       speechiness    tempo   energy
# 0          0.3690  125.044  0.93600
# 1          0.0439   87.431  0.00555
# ...

# %%
df_E.to_csv("Energy_feature.csv")

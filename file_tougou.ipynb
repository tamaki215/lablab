# %%
import glob
import pandas as pd



df1 = pd.read_csv("2008.csv",index_col=0)
df2 = pd.read_csv("2009.csv",index_col=0)
df3 = pd.read_csv("2010.csv",index_col=0)
df4 = pd.read_csv("2011.csv",index_col=0)
df5 = pd.read_csv("2012.csv",index_col=0)
df6 = pd.read_csv("2013.csv",index_col=0)
df7 = pd.read_csv("2014.csv",index_col=0)
df8 = pd.read_csv("2015.csv",index_col=0)
df9 = pd.read_csv("2016.csv",index_col=0)
df10 = pd.read_csv("2017.csv",index_col=0)
df11 = pd.read_csv("2018.csv",index_col=0)
df12 = pd.read_csv("2019.csv",index_col=0)
df13 = pd.read_csv("2020.csv",index_col=0)
df14 = pd.read_csv("2021.csv",index_col=0)

alldf = pd.concat([df1, df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14], axis=0)
print (alldf)

alldf.to_csv('alldf.csv')
# Out:
#                        uri              name                album  \
# 0   2bzdhN6Y5AP1zRRf12QwJq               キセキ                  キセキ
# 1   1Rvh5RimhF3ndpclBmIdeJ            そばにいるね               そばにいるね
# 2   52mKiP16FYA0C8X6gTr4zK  I AM YOUR SINGER     I AM YOUR SINGER
# 3   0AU7xhipAm9Saq0k8A9Iua            HANABI  SUPERMARKET FANTASY
# 4   7cWujxmEVy0ru9y1uGCs4N              LIFE                 LIFE
# ..                     ...               ...                  ...
# 89  5gh0y6ZmuppQvoPbAGkeE2           愛を知るまでは              愛を知るまでは
# 90  7Fuv1ELyHOYkRbPvRpN4vo         Rocketeer            Rocketeer
# 91  22sQUmLhT8umlEhQzDrzfJ               第六感                  第六感
# 92  2sQDwbzGSpHXwnIAOrcDn9            グッバイ宣言               グッバイ宣言
# 93  4W29WmnGN1FlufURaBt8yw             怪獣の花唄               strobo
#
#            artist  genre release_date  length  mode  popularity  danceability  \
# 0         GReeeeN      0   2008-06-04  271880     1          51         0.642
# ...

# %%
alldf.to_csv('bestsong.csv', header=True, index=False)

# %%
df = pd.read_csv("bestsong.csv")
df
# Out:
#                          uri              name                album  \
# 0     2bzdhN6Y5AP1zRRf12QwJq               キセキ                  キセキ
# 1     1Rvh5RimhF3ndpclBmIdeJ            そばにいるね               そばにいるね
# 2     52mKiP16FYA0C8X6gTr4zK  I AM YOUR SINGER     I AM YOUR SINGER
# 3     0AU7xhipAm9Saq0k8A9Iua            HANABI  SUPERMARKET FANTASY
# 4     7cWujxmEVy0ru9y1uGCs4N              LIFE                 LIFE
# ...                      ...               ...                  ...
# 1116  5gh0y6ZmuppQvoPbAGkeE2           愛を知るまでは              愛を知るまでは
# 1117  7Fuv1ELyHOYkRbPvRpN4vo         Rocketeer            Rocketeer
# 1118  22sQUmLhT8umlEhQzDrzfJ               第六感                  第六感
# 1119  2sQDwbzGSpHXwnIAOrcDn9            グッバイ宣言               グッバイ宣言
# 1120  4W29WmnGN1FlufURaBt8yw             怪獣の花唄               strobo
#
#              artist  genre release_date  length  mode  popularity  \
# 0           GReeeeN      0   2008-06-04  271880     1          51
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1116    False
# 1117    False
# 1118    False
# 1119    False
# 1120    False
# Length: 1121, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 139

# %%
df = df.drop_duplicates()

# %%
df.reset_index(drop=True)
# Out:
#                         uri              name                album  \
# 0    2bzdhN6Y5AP1zRRf12QwJq               キセキ                  キセキ
# 1    1Rvh5RimhF3ndpclBmIdeJ            そばにいるね               そばにいるね
# 2    52mKiP16FYA0C8X6gTr4zK  I AM YOUR SINGER     I AM YOUR SINGER
# 3    0AU7xhipAm9Saq0k8A9Iua            HANABI  SUPERMARKET FANTASY
# 4    7cWujxmEVy0ru9y1uGCs4N              LIFE                 LIFE
# ..                      ...               ...                  ...
# 977  5gh0y6ZmuppQvoPbAGkeE2           愛を知るまでは              愛を知るまでは
# 978  7Fuv1ELyHOYkRbPvRpN4vo         Rocketeer            Rocketeer
# 979  22sQUmLhT8umlEhQzDrzfJ               第六感                  第六感
# 980  2sQDwbzGSpHXwnIAOrcDn9            グッバイ宣言               グッバイ宣言
# 981  4W29WmnGN1FlufURaBt8yw             怪獣の花唄               strobo
#
#             artist  genre release_date  length  mode  popularity  \
# 0          GReeeeN      0   2008-06-04  271880     1          51
# ...

# %%
df.to_csv('bestsong.csv', header=True, index=False)

# %%
print('test')
# Out:
# test
